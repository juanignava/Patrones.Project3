# %%
from keras.models import Model
from keras.layers import Input, Dense
import os
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.optimizers import Adam
import matplotlib.pyplot as plt

from keras.layers import Conv2D, Conv2DTranspose, Flatten, MaxPooling2D, UpSampling2D, Reshape

# %%
"""
-- Load data from analysis dataset --
"""

parent_folder_path = "images/analysis_dataset/"

categories = {}

# Iterate over the contents of the "original_dataset" folder
for index, folder_name in enumerate(sorted(os.listdir(parent_folder_path))):
    folder_path = os.path.join(parent_folder_path, folder_name)
    if os.path.isdir(folder_path):
        categories[folder_name] = index

category_amount = []

# get the category with the least images
for category in categories.keys():
    folder_path = os.path.join(parent_folder_path, category)
    image_files = os.listdir(folder_path)
    category_amount.append(len(image_files))

max_training = min(category_amount)

arrays = []
# convert the images into a pytorch dataset
for cat_folder, value in categories.items():

    folder_path = os.path.join(parent_folder_path, cat_folder)
    image_files = os.listdir(folder_path)

    for i, file_name in enumerate(image_files):

        if i >= max_training: break
        file_path = os.path.join(folder_path, file_name)
        image = Image.open(file_path)
        image_array = np.array(image)

        # verify all images are of the desired size
        if image.size != (100, 100):
            print(file_path, " IS NOT 250x250, it is: ", image.size)
            continue

        if image_array.shape != (250, 250):
            image_array = np.dot(image_array[..., :3], [0.2989, 0.5870, 0.1140])

        arrays.append(image_array)

# Normalize the array of the normal 
arrays = arrays/ np.max(arrays)

arrays_labels = []
for i in range(len(categories)):
    arrays_labels += [i] * max_training

arrays_labels_normal = np.array(arrays_labels)

# %%
"""
-- Load autoencoder, train and testing data --

Using the distribution:
80% -> autoencoder
10% -> training data
10% -> testing data
"""

X_auto, X, y_auto, y = train_test_split(arrays, arrays_labels, test_size=0.5, random_state=42, stratify=arrays_labels)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42, stratify=y)

y_train = to_categorical(y_train, num_classes=38)
y_test = to_categorical(y_test, num_classes=38)

"""
X_auto = np.array(X_auto)
X_auto = X_auto.reshape((len(X_auto), -1))

X_train = np.array(X_train)
X_train = X_train.reshape((len(X_train), -1))

X_test = np.array(X_test)
X_test = X_test.reshape((len(X_test), -1))

X = np.array(X)
X = X.reshape((len(X), -1))
"""

X_auto = X_auto.reshape((len(X_auto), 100, 100))
X_train = X_train.reshape((len(X_train), 100, 100))

X_test = X_test.reshape((len(X_test), 100, 100))

# %%
# definir la arquitectura del autoencoder

input_img = Input(shape=(100, 100, 1))
encoded = Conv2D(1, (3, 3), activation='relu', padding='same')(input_img)
encoded = MaxPooling2D((2,2), padding='same')(encoded)
encoded = Flatten()(encoded)
latent = Dense(150, activation='relu')(encoded)
decoded = Dense(2500, activation='relu')(latent)
decoded = Reshape((50, 50, 1))(decoded)
decoded = UpSampling2D((2, 2))(decoded)
decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(decoded)

# Crear el modelo del autoencoder
autoencoder = Model(input_img, decoded)

# Compilar el modelo
optimizer = Adam(learning_rate = 0.01)
autoencoder.compile(optimizer=optimizer, loss='binary_crossentropy')

print("Before fit autoencoder")

# Entrenar el autoencoder
autoencoder.fit(X_auto, X_auto,
                epochs=4,
                batch_size=256,
                shuffle=True,
                validation_data=(X, X))

print("after autoencoder")
# Obtener el vector latente (representación codificada)
encoder = Model(input_img, latent)
encoded_train = encoder.predict(X_train)
encoded_test = encoder.predict(X_test)
# Out:
# Before fit autoencoder
# Epoch 1/4
# 86/86 [==============================] - 40s 462ms/step - loss: 0.6705 - val_loss: 0.6673
# Epoch 2/4
# 86/86 [==============================] - 30s 355ms/step - loss: 0.6657 - val_loss: 0.6644
# Epoch 3/4
# 86/86 [==============================] - 30s 345ms/step - loss: 0.6638 - val_loss: 0.6635
# Epoch 4/4
# 86/86 [==============================] - 30s 349ms/step - loss: 0.6626 - val_loss: 0.6627
# after autoencoder
# 582/582 [==============================] - 6s 9ms/step
# 103/103 [==============================] - 1s 9ms/step

# %%
reconstructed_imgs = autoencoder.predict(X_test)

n = 5  # número de imágenes a mostrar
plt.figure(figsize=(20, 4))
for i in range(n):
    # Imagen original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(100, 100))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Imagen reconstruida
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(reconstructed_imgs[i].reshape(100, 100))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 103/103 [==============================] - 2s 15ms/step

# %%
# Definir la arquitectura del clasificador utilizando el vector latente como entrada
input_latent = Input(shape=(150,))
output = Dense(128, activation='softmax')(input_latent)
output = Dense(64, activation='softmax')(input_latent)
output = Dense(38, activation='softmax')(input_latent)

# Crear el modelo del clasificador
classifier = Model(input_latent, output)

# Compilar el modelo del clasificador
optimizer = Adam(learning_rate = 0.0001)
classifier.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenar el clasificador utilizando el vector latente como características de entrada
classifier.fit(encoded_train, y_train,
               epochs=200,
               batch_size=256,
               validation_data=(encoded_test, y_test), verbose=1)

# Evaluar el rendimiento del clasificador en el conjunto de prueba
loss, accuracy = classifier.evaluate(encoded_test, y_test)
print("Pérdida de clasificación:", loss)
print("Exactitud de clasificación:", accuracy)
# Out:
# Epoch 1/200
# 73/73 [==============================] - 1s 6ms/step - loss: 3.6517 - accuracy: 0.0254 - val_loss: 3.6507 - val_accuracy: 0.0265
# Epoch 2/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6503 - accuracy: 0.0254 - val_loss: 3.6495 - val_accuracy: 0.0271
# Epoch 3/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6490 - accuracy: 0.0249 - val_loss: 3.6483 - val_accuracy: 0.0283
# Epoch 4/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6478 - accuracy: 0.0250 - val_loss: 3.6472 - val_accuracy: 0.0283
# Epoch 5/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6467 - accuracy: 0.0252 - val_loss: 3.6461 - val_accuracy: 0.0295
# Epoch 6/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6456 - accuracy: 0.0254 - val_loss: 3.6452 - val_accuracy: 0.0301
# Epoch 7/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6446 - accuracy: 0.0255 - val_loss: 3.6442 - val_accuracy: 0.0311
# Epoch 8/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6437 - accuracy: 0.0255 - val_loss: 3.6434 - val_accuracy: 0.0301
# Epoch 9/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6428 - accuracy: 0.0268 - val_loss: 3.6426 - val_accuracy: 0.0298
# Epoch 10/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6420 - accuracy: 0.0266 - val_loss: 3.6418 - val_accuracy: 0.0298
# Epoch 11/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6412 - accuracy: 0.0271 - val_loss: 3.6411 - val_accuracy: 0.0323
# Epoch 12/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6404 - accuracy: 0.0274 - val_loss: 3.6404 - val_accuracy: 0.0308
# Epoch 13/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6397 - accuracy: 0.0278 - val_loss: 3.6397 - val_accuracy: 0.0317
# Epoch 14/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6390 - accuracy: 0.0274 - val_loss: 3.6391 - val_accuracy: 0.0317
# Epoch 15/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6383 - accuracy: 0.0288 - val_loss: 3.6385 - val_accuracy: 0.0332
# Epoch 16/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6376 - accuracy: 0.0295 - val_loss: 3.6379 - val_accuracy: 0.0338
# Epoch 17/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.
200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6138 - accuracy: 0.0423 - val_loss: 3.6176 - val_accuracy: 0.0405
# Epoch 79/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6135 - accuracy: 0.0428 - val_loss: 3.6174 - val_accuracy: 0.0417
# Epoch 80/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6133 - accuracy: 0.0431 - val_loss: 3.6172 - val_accuracy: 0.0408
# Epoch 81/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6130 - accuracy: 0.0430 - val_loss: 3.6169 - val_accuracy: 0.0408
# Epoch 82/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6127 - accuracy: 0.0431 - val_loss: 3.6167 - val_accuracy: 0.0405
# Epoch 83/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6125 - accuracy: 0.0437 - val_loss: 3.6165 - val_accuracy: 0.0417
# Epoch 84/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6122 - accuracy: 0.0438 - val_loss: 3.6163 - val_accuracy: 0.0426
# Epoch 85/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6120 - accuracy: 0.0432 - val_loss: 3.6161 - val_accuracy: 0.0417
# Epoch 86/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6117 - accuracy: 0.0432 - val_loss: 3.6159 - val_accuracy: 0.0417
# Epoch 87/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6115 - accuracy: 0.0432 - val_loss: 3.6157 - val_accuracy: 0.0411
# Epoch 88/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6112 - accuracy: 0.0438 - val_loss: 3.6155 - val_accuracy: 0.0396
# Epoch 89/200
# 73/73 [==============================] - 0s 4ms/step - loss: 3.6110 - accuracy: 0.0439 - val_loss: 3.6153 - val_accuracy: 0.0411
# Epoch 90/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6107 - accuracy: 0.0444 - val_loss: 3.6152 - val_accuracy: 0.0402
# Epoch 91/200
# 73/73 [==============================] - 0s 3ms/step - loss: 3.6105 - accuracy: 0.0439 - val_loss: 3.6150 - val_accuracy: 0.0411
# Epoch 92/200
# 20/73 [=======>......................] - ETA: 0s - loss: 3.6099 - accuracy: 0.0471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 15
#      12 classifier.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
#      14 # Entrenar el clasificador utilizando el vector latente como características de entrada
# ---> 15 classifier.fit(encoded_train, y_train,
#      16                epochs=200,
#      17                batch_size=256,
#      18                validation_data=(encoded_test, y_test), verbose=1)
#      20 # Evaluar el rendimiento del clasificador en el conjunto de prueba
#      21 loss, accuracy = classifier.evaluate(encoded_test, y_test)
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\training.py:1676, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1674 callbacks.on_epoch_begin(epoch)
#    1675 with data_handler.catch_stop_iteration():
# -> 1676     for step in data_handler.steps():
#    1677         with tf.profiler.experimental.Trace(
#    1678             "train",
#    1679             epoch_num=epoch,
#    (...)
#    1682             _r=1,
#    1683         ):
#    1684             callbacks.on_train_batch_begin(step)
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\engine\data_adapter.py:1375, in DataHandler.steps(self)
#    1373 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1374     break
# -> 1375 original_spe = self._steps_per_execution.numpy().item()
#    1376 can_run_full_execution = (
#    1377     original_spe == 1
#    1378     or self._inferred_steps is None
#    1379     or self._inferred_steps - self._current_step >= original_spe
#    1380 )
#    1382 if can_run_full_execution:
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:647, in BaseResourceVariable.numpy(self)
#     645 def numpy(self):
#     646   if context.executing_eagerly():
# --> 647     return self.read_value().numpy()
#     648   raise NotImplementedError(
#     649       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:774, in BaseResourceVariable.read_value(self)
#     765 """Constructs an op which reads the value of this variable.
#     766
#     767 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     771   The value of the variable.
#     772 """
#     773 with ops.name_scope("Read"):
# --> 774   value = self._read_variable_op()
#     775 # Return an identity so it can get placed on whatever device the context
#     776 # specifies instead of the device where the variable is.
#     777 return array_ops.identity(value)
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:753, in BaseResourceVariable._read_variable_op(self, no_copy)
#     751       result = read_and_set_handle(no_copy)
#     752 else:
# --> 753   result = read_and_set_handle(no_copy)
#     755 if not context.executing_eagerly():
#     756   # Note that if a control flow context is active the input of the read op
#     757   # might not actually be the handle. This line bypasses it.
#     758   tape.record_operation(
#     759       "ReadVariableOp", [result], [self.handle],
#     760       backward_function=lambda x: [x],
#     761       forward_function=lambda x: [x])
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:743, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     741 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     742   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 743 result = gen_resource_variable_ops.read_variable_op(
#     744     self.handle, self._dtype)
#     745 _maybe_set_handle_data(self._dtype, self.handle, result)
#     746 return result
#
# File c:\Users\Juan Navarro\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:580, in read_variable_op(resource, dtype, name)
#     578 if tld.is_eager:
#     579   try:
# --> 580     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     581       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     582     return _result
#     583   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
